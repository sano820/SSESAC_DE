# %%
import os
from dotenv import load_dotenv
load_dotenv()

API_KEY = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# 1. client.chat.completions.create
# 2. client.response.create

# %% [markdown]
# ### Langchain_openai
# https://docs.langchain.com/oss/python/integrations/chat/openai

# %%
from langchain_openai import ChatOpenAI

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="gpt-4o",
    # stream_usage=True,
    temperature=0.1,
    # max_tokens=None,
    # timeout=None,
    # reasoning_effort="low",
    # max_retries=2,
    # api_key="...",  # If you prefer to pass api key in directly
    # base_url="...",
    # organization="...",
    # other params...
)

# %%
messages = [
    {
        'role':'system', 'content':'너는 친절한 한국어 튜어야.',
        'role':'user','content':'Langchain에 대해서 설명해줘'
     }
]

# %%
from openai import OpenAI

client = OpenAI()

response = client.chat.completions.create(model='gpt-4o-mini',
                                          messages=messages,
                                          temperature=0.1)

# %%
# response = dict(response)
print(response)
# Out:
# ChatCompletion(id='chatcmpl-CnHDb9PiMinzHMS1EgIiLdATugdZd', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='Langchain은 자연어 처리(NLP)와 관련된 다양한 작업을 수행하기 위한 프레임워크로, 특히 대화형 AI 애플리케이션을 구축하는 데 유용합니다. 이 프레임워크는 여러 가지 모듈과 구성 요소를 제공하여 개발자가 언어 모델을 쉽게 통합하고, 데이터 소스와 상호작용하며, 복잡한 작업을 처리할 수 있도록 돕습니다.\n\nLangchain의 주요 기능은 다음과 같습니다:\n\n1. **모델 통합**: 다양한 언어 모델(예: OpenAI의 GPT, Hugging Face의 Transformers 등)을 쉽게 통합할 수 있습니다.\n\n2. **체인**: 여러 작업을 연결하여 복잡한 프로세스를 구성할 수 있는 체인 구조를 제공합니다. 예를 들어, 질문 응답, 요약, 번역 등의 작업을 순차적으로 수행할 수 있습니다.\n\n3. **데이터 소스 연결**: 데이터베이스, API, 파일 시스템 등 다양한 데이터 소스와 연결하여 정보를 가져오고 처리할 수 있습니다.\n\n4. **프롬프트 관리**: 언어 모델에 대한 프롬프트를 쉽게 관리하고 최적화할 수 있는 도구를 제공합니다.\n\n5. **사용자 정의**: 개발자가 필요에 따라 기능을 확장하거나 수정할 수 있는 유연성을 제공합니다.\n\nLangchain은 대화형 AI, 챗봇, 정보 검색 시스템 등 다양한 애플리케이션에 활용될 수 있으며, 개발자들이 보다 효율적으로 작업할 수 있도록 돕는 강력한 도구입니다.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1765860295, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier='default', system_fingerprint='fp_ee69c2ef48', usage=CompletionUsage(completion_tokens=336, prompt_tokens=14, total_tokens=350, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))

# %%
print(response.choices[0].message.content)
# Out:
# Langchain은 자연어 처리(NLP)와 관련된 다양한 작업을 수행하기 위한 프레임워크로, 특히 대화형 AI 애플리케이션을 구축하는 데 유용합니다. 이 프레임워크는 여러 가지 모듈과 구성 요소를 제공하여 개발자가 언어 모델을 쉽게 통합하고, 데이터 소스와 상호작용하며, 복잡한 작업을 처리할 수 있도록 돕습니다.
#
# Langchain의 주요 기능은 다음과 같습니다:
#
# 1. **모델 통합**: 다양한 언어 모델(예: OpenAI의 GPT, Hugging Face의 Transformers 등)을 쉽게 통합할 수 있습니다.
#
# 2. **체인**: 여러 작업을 연결하여 복잡한 프로세스를 구성할 수 있는 체인 구조를 제공합니다. 예를 들어, 질문 응답, 요약, 번역 등의 작업을 순차적으로 수행할 수 있습니다.
#
# 3. **데이터 소스 연결**: 데이터베이스, API, 파일 시스템 등 다양한 데이터 소스와 연결하여 정보를 가져오고 처리할 수 있습니다.
#
# 4. **프롬프트 관리**: 언어 모델에 대한 프롬프트를 쉽게 관리하고 최적화할 수 있는 도구를 제공합니다.
#
# 5. **사용자 정의**: 개발자가 필요에 따라 기능을 확장하거나 수정할 수 있는 유연성을 제공합니다.
#
# Langchain은 대화형 AI, 챗봇, 정보 검색 시스템 등 다양한 애플리케이션에 활용될 수 있으며, 개발자들이 보다 효율적으로 작업할 수 있도록 돕는 강력한 도구입니다.

# %% [markdown]
# ### 프롬프트 넣어보기

# %%
from openai import OpenAI
client = OpenAI()

# %%
prompt = '''다음 요리의 레시피를 생각해주세요.
요리명 : """{dish}"""
'''

# def generate_recipe(dish: str) -> str:
def generate_recipe(dish):
    messages = [{'role':'user', 'content':prompt.format(dish=dish)}]
    response = client.chat.completions.create(model = 'gpt-4o-mini',
                                              messages = messages)
    return response.choices[0].message.content

# %%
recipe = generate_recipe('라면')

# %%
print(recipe)
# Out:
# 라면은 간단하면서도 다양한 변화를 줄 수 있는 인기 있는 요리입니다. 여기 기본적인 라면 레시피를 소개하겠습니다.
#
# ### 기본 라면 레시피
#
# #### 재료
# - 인스턴트 라면 1봉지
# - 물 550ml (약 2컵)
# - 계란 1개 (선택 사항)
# - 대파 1/2대 (다져서)
# - 고춧가루 또는 후추 (선택 사항)
# - 기타 재료 (예: 채소, 고기, 해산물 등, 선택 사항)
#
# #### 조리 방법
# 1. **물 끓이기**: 냄비에 물을 붓고 중불로 끓입니다.
#
# 2. **면 넣기**: 물이 끓어오르면 인스턴트 라면 면을 넣고 2-3분간 끓입니다.
#    - 면을 조금 더 쫄깃하게 먹고 싶다면, 끓이는 시간을 줄일 수 있습니다.
#
# 3. **스프 추가**: 면이 익기 시작하면 라면 스프를 넣고 잘 저어줍니다.
#
# 4. **계란 추가 (선택 사항)**: 계란을 추가하고 싶다면, 스프를 넣은 후 계란을 중간에 깨서 넣습니다. 계란을 저어서 스크램블 에그처럼 해도 좋고, 그대로 두어 반숙으로 해도 좋습니다.
#
# 5. **추가 재료 넣기 (선택 사항)**: 원하는 경우 대파, 채소 (예: 시금치, 양배추, 버섯 등), 고기 (예: 소시지, 베이컨 등), 해산물 (예: 새우, 오징어 등)을 추가합니다. 이 재료들은 면과 함께 익히면 됩니다.
#
# 6. **간 조절**: 볶음 고춧가루나 후추 등을 추가하여 개인의 취향에 맞게 간을 조절합니다.
#
# 7. **서빙**: 모두 잘 섞이고 익은 후, 그릇에 담아 맛있게 즐기세요!
#
# ### 팁
# - 라면의 종류에 따라 조리 시간이나 물의 양이 조금 다를 수 있으니, 포장지를 참고하는 것이 좋습니다.
# - 매운 라면을 원하시면 고추장이나 고춧가루를 추가해 보세요.
# - 다양한 토핑을 이용해 나만의 특별한 라면을 만들어 보세요!
#
# 맛있게 드세요!

# %%
def generate_recipe(dish):
    messages = [{'role':'system', 'content':'사용자가 입력한 요리의 레시피를 생각해주세요.'},
                {'role':'user', 'content':f"{dish}"}]
    response = client.chat.completions.create(model = 'gpt-4o-mini',
                                              messages = messages)
    return response.choices[0].message.content

# %%
recipe = generate_recipe('라면')
print(recipe)
# Out:
# 라면은 간편하게 만들 수 있는 인기 있는 요리입니다. 여기 기본적인 라면 레시피를 소개해드릴게요.
#
# ### 재료:
# - 라면 1개 (원하는 종류)
# - 물 550ml
# - 스프 (라면 봉지 안에 들어있는)
# - 선택 재료 (옵션):
#   - 계란 1개
#   - 파, 청양고추, 양파, 버섯, 또는 원하는 채소
#   - 김치
#   - 치즈
#
# ### 조리 방법:
# 1. **물 끓이기**: 냄비에 물 550ml를 붓고 중불에 올려 끓입니다.
#
# 2. **면 넣기**: 물이 끓기 시작하면 라면 면을 넣습니다. 면이 부드러워질 때까지 약 3-4분 정도 익힙니다.
#
# 3. **스프 추가**: 면이 익으면 라면 봉지에 들어 있는 스프를 넣고 잘 저어줍니다. 이후 원하는 선택 재료(계란, 채소 등)를 추가합니다.
#
# 4. **계란 추가하기 (옵션)**: 계란을 넣고 잘 섞으면 끓는 동안 계란이 익어 맛있게 섞입니다.
#
# 5. **마무리**: 모든 재료가 잘 섞이고 익으면 불을 끄고 그릇에 담습니다. 김치나 치즈를 나중에 올려서 맛을 더할 수 있습니다.
#
# 6. **서빙**: 뜨거운 라면을 즐기세요!
#
# ### 팁:
# - 매운 맛을 원한다면 청양고추를 썰어 넣거나, 고춧가루를 추가하세요.
# - 크림 같은 맛을 원한다면 라면이 다 끓고 난 후에 치즈 한 장을 올려서 녹여보세요.
#
# 여러 가지 방법으로 라면을 더욱 맛있게 즐길 수 있습니다!

# %%
system_prompt = """\
사용자가 입력한 요리의 레시피를 생각해 주세요.。

출력은 다음 JSON 형식으로 해주세요.

{
  "재료": ["재료1", "재료2"],
  "순서": ["순서1", "순서2"]
}

"""
messages = [
    {'role':'system','content':system_prompt},
    {'role':'user','content':'카레'}
]
response = client.chat.completions.create(model = 'gpt-5o-nano', messages = messages)
print(response.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[14], line 16
#       1 system_prompt = """\
#       2 사용자가 입력한 요리의 레시피를 생각해 주세요.。
#       3
#    (...)     10
#      11 """
#      12 messages = [
#      13     {'role':'system','content':system_prompt},
#      14     {'role':'user','content':'카레'}
#      15 ]
# ---> 16 response = client.chat.completions.create(model = 'gpt-5o-nano', messages = messages)
#      17 print(response.choices[0].message.content)
#
# File c:\Users\USER\miniconda3\envs\langchain_env\Lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File c:\Users\USER\miniconda3\envs\langchain_env\Lib\site-packages\openai\resources\chat\completions\completions.py:1192, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1145 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1146 def create(
#    1147     self,
#    (...)   1189     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1190 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1191     validate_response_format(response_format)
# -> 1192     return self._post(
#    1193         "/chat/completions",
#    1194         body=maybe_transform(
#    1195             {
#    1196                 "messages": messages,
#    1197                 "model": model,
#    1198                 "audio": audio,
#    1199                 "frequency_penalty": frequency_penalty,
#    1200                 "function_call": function_call,
#    1201                 "functions": functions,
#    1202                 "logit_bias": logit_bias,
#    1203                 "logprobs": logprobs,
#    1204                 "max_completion_tokens": max_completion_tokens,
#    1205                 "max_tokens": max_tokens,
#    1206                 "metadata": metadata,
#    1207                 "modalities": modalities,
#    1208                 "n": n,
#    1209                 "parallel_tool_calls": parallel_tool_calls,
#    1210                 "prediction": prediction,
#    1211                 "presence_penalty": presence_penalty,
#    1212                 "prompt_cache_key": prompt_cache_key,
#    1213                 "prompt_cache_retention": prompt_cache_retention,
#    1214                 "reasoning_effort": reasoning_effort,
#    1215                 "response_format": response_format,
#    1216                 "safety_identifier": safety_identifier,
#    1217                 "seed": seed,
#    1218                 "service_tier": service_tier,
#    1219                 "stop": stop,
#    1220                 "store": store,
#    1221                 "stream": stream,
#    1222                 "stream_options": stream_options,
#    1223                 "temperature": temperature,
#    1224                 "tool_choice": tool_choice,
#    1225                 "tools": tools,
#    1226                 "top_logprobs": top_logprobs,
#    1227                 "top_p": top_p,
#    1228                 "user": user,
#    1229                 "verbosity": verbosity,
#    1230                 "web_search_options": web_search_options,
#    1231             },
#    1232             completion_create_params.CompletionCreateParamsStreaming
#    1233             if stream
#    1234             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1235         ),
#    1236         options=make_request_options(
#    1237             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1238         ),
#    1239         cast_to=ChatCompletion,
#    1240         stream=stream or False,
#    1241         stream_cls=Stream[ChatCompletionChunk],
#    1242     )
#
# File c:\Users\USER\miniconda3\envs\langchain_env\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\USER\miniconda3\envs\langchain_env\Lib\site-packages\openai\_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# NotFoundError: Error code: 404 - {'error': {'message': 'The model `gpt-5o-nano` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}

# %%
messages = [
    {'role':'system','content':'입력을 긍적적, 부정적, 중립 중 하나로 분류하세요.'},
    {'role':'user','content':'ChatGPT는 매우 편리하다.'}
]
response = client.chat.completions.create(model = 'gpt-4o-mini', messages = messages)
print(response.choices[0].message.content)
# Out:
# 긍정적

# %% [markdown]
# ### Few-shot

# %%
messages=[
        {"role": "system", "content": "입력이 AI와 관련이 있는지 답변해 주세요."},
        {"role": "user", "content": "AI의 진화는 대단하다"},
        {"role": "assistant", "content": "true"},
        {"role": "user", "content": "오늘은 날씨가 좋다"},
        {"role": "assistant", "content": "false"},
        {"role": "user", "content": "ChatGPT는 매우 편리하다"},
    ]

# %%
response = client.chat.completions.create(model = 'gpt-4o-mini', messages = messages)
print(response.choices[0].message.content)
# Out:
# true

# %%
def RIP(messages):
    response = client.chat.completions.create(model = 'gpt-4o-mini', messages = messages)
    print(response.choices[0].message.content)

# %%
messages=[
        {"role": "system", "content": "답변만 한 마디로 출력해 주세요."},
        {"role": "user", "content": "10 + 2 * 3 - 4 * 2"},
    ]

# %%
RIP(messages)
# Out:
# 6

# %%
messages=[
        {"role": "system", "content": "단계별로 생각해 주세요."},
        {"role": "user", "content": "10 + 2 * 3 - 4 * 2"},
    ]

# %%
RIP(messages)
# Out:
# 계산을 단계별로 진행해 보겠습니다.
#
# 1. 먼저 곱셈을 수행합니다:
#    - \(2 * 3 = 6\)
#    - \(4 * 2 = 8\)
#
# 2. 이제 이 값을 원래 식에 대입하여 새 식을 만듭니다:
#    - \(10 + 6 - 8\)
#
# 3. 다음으로 덧셈과 뺄셈을 왼쪽에서 오른쪽으로 순서대로 수행합니다:
#    - \(10 + 6 = 16\)
#    - \(16 - 8 = 8\)
#
# 따라서, 최종 결과는 \(8\)입니다.

# %%
from openai import AsyncOpenAI, OpenAI

# %%
sync_client = OpenAI()
async_client = AsyncOpenAI()

# %%
def llm_call(prompt: str, model: str = 'gpt-4o-mini') -> str:
    messages = []
    messages.append({'role':'user','content':prompt})
    chat_completion = sync_client.chat.completions.create(
        model = model,
        messages=messages
    )
    return chat_completion.choices[0].message.content

# %%
from typing import List

def prompt_chain_workflow_2(initial_input:str, prompt_chain:List[str]) -> List[str]:
    response_chain = []
    response = initial_input
    for i, prompt in enumerate(prompt_chain, 1):
        print(f"\n == 단계 {i} == \n")
        final_prompt = f'{prompt} \n\n 문맥(Context):\n {response} \n 사용자 입력 : {initial_input}'
        print(f' 프롬프트 : \n {final_prompt} \n')
        response = llm_call(final_prompt)
        response_chain.append(response)
    return response_chain

# %%
initial_input ="""
나는 여름 휴가를 계획 중이야. 따뜻한 날씨를 좋아하고, 자연 경관과 역사적인 장소를 둘러보는 걸 좋아해.
어떤 여행지가 나에게 적합할까?
"""

# %%
prompt_chain = [
    ## 여행 후보지 3곳을 추천하고 그 이유를 설명
"""사용자의 여행 취향을 바탕으로 적합한 여행지 3곳을 추천하세요.
먼저 사용자가 입력한 희망사항을 요약해줘
사용자가 입력한 희망사항을 반영해서 왜 적합한 여행지인지 설명해주세요
각 여행지의 기후, 주요 관광지, 활동 등을 설명하세요.
""",

    ## 여행지 1곳을 선택하고 활동 5가지 나열
"""다음 여행지 3곳 중 하나를 선택하세요. 선택한 여행지 알려주세요. 그리고 선택한 이유를 설명해주세요.
해당 여행지에서 즐길 수 있는 주요 활동 5가지를 나열하세요.
활동은 자연 탐방, 역사 탐방, 음식 체험 등 다양한 범주에서 포함되도록 하세요.
""",

    ## 선택한 여행지에서 하루 일정 계획
"""사용자가 하루 동안 이 여행지에서 시간을 보낼 계획입니다.
오전, 오후, 저녁으로 나누어 일정을 짜고, 각 시간대에 어떤 활동을 하면 좋을지 설명하세요.
"""
]

# %%
responses = prompt_chain_workflow_2(initial_input, prompt_chain)
final_answer = responses[-1]
print(final_answer)
# Out:
#  == 단계 1 ==
#
#  프롬프트 :
#  사용자의 여행 취향을 바탕으로 적합한 여행지 3곳을 추천하세요.
# 먼저 사용자가 입력한 희망사항을 요약해줘
# 사용자가 입력한 희망사항을 반영해서 왜 적합한 여행지인지 설명해주세요
# 각 여행지의 기후, 주요 관광지, 활동 등을 설명하세요.
#
#
#  문맥(Context):
#
# 나는 여름 휴가를 계획 중이야. 따뜻한 날씨를 좋아하고, 자연 경관과 역사적인 장소를 둘러보는 걸 좋아해.
# 어떤 여행지가 나에게 적합할까?
#
#  사용자 입력 :
# 나는 여름 휴가를 계획 중이야. 따뜻한 날씨를 좋아하고, 자연 경관과 역사적인 장소를 둘러보는 걸 좋아해.
# 어떤 여행지가 나에게 적합할까?
#
#
#
#  == 단계 2 ==
#
#  프롬프트 :
#  다음 여행지 3곳 중 하나를 선택하세요. 선택한 여행지 알려주세요. 그리고 선택한 이유를 설명해주세요.
# 해당 여행지에서 즐길 수 있는 주요 활동 5가지를 나열하세요.
# 활동은 자연 탐방, 역사 탐방, 음식 체험 등 다양한 범주에서 포함되도록 하세요.
#
#
#  문맥(Context):
#  사용자의 희망사항 요약:
# - 여름 휴가 계획
# - 따뜻한 날씨 선호
# - 자연 경관과 역사적인 장소 탐방 선호
#
# 이러한 취향을 바탕으로 추천할 수 있는 여행지 3곳은 다음과 같습니다:
#
# ### 1. 산토리니, 그리스
# **기후:** 여름에 평균 기온은 28~30도이며, 맑고 따뜻한 날씨가 이어집니다.
#
# **주요 관광지:**
# - **오이아 마을:** 하얀 집과 파란 지붕이 있는 그림 같은 마을로, 일몰이 유명합니다.
# - **페리사 해변:** 검은 모래 해변에서 바다를 즐기거나, 주변의 레스토랑에서 그리스 요리를 맛볼 수 있습니다.
# - **고대 티라 유적지:** 그리스 고대 문명의 흔적을 고스란히 간직한 곳으로, 역사에 관심이 많은 여행자에게 매우 흥미로운 장소입니다.
#
# **활동:**
# - 섬의 아름다운 경치를 감상하며 하이킹을 할 수 있고, 보트 투어를 통해 인근 섬들을 탐험할 수 있습니다. 또한 와인 시음 투어도 인기입니다.
#
# ### 2. 바르셀로나, 스페인
# **기후:** 여름철 평균 기온은 25~30도이며, 따뜻하고 화창한 날씨가 특징입니다.
#
# **주요 관광지:**
# - **사그라다 파밀리아:** 가우디의 걸작으로, 독특한 건축 양식을 감상할 수 있습니다.
# - **구엘 공원:** 다채로운 타일과 자연이 조화로운 공원으로, 산책하기 좋은 곳입니다.
# - **고딕 지구:** 중세 건축물들이 잘 보존된 지역으로, 역사적인 분위기를 느낄 수 있습니다.
#
# **활동:**
# - 해변에서 일광욕을 즐기거나, 다양한 문화 행사와 미술관을 탐방할 수 있습니다. 또한, 전통적인 스페인 요리인 타파스를 즐기는 것도 좋습니다.
#
# ### 3. 라오스, 루앙프라방
# **기후:** 여름에 평균 기온은 30도 이상이며, 덥고 습한 날씨가 특징입니다.
#
# **주요 관광지:**
# - **왓 시리 끼엥:** 고대 사원으로 아름다운 불교 건축을 감상할 수 있습니다.
# - **쿠앙 시 폭포:** 환상적인 자연 경관을 자랑하며, 수영을 즐길 수 있는 장소로 유명합니다.
# - **킹 루앙 왕궁:** 라오스의 역사적이고 문화적인 자산을 소개하는 박물관으로, 여행자가 라오스의 역사에 대해 배울 수 있는 좋은 곳입니다.
#
# **활동:**
# - 폭포에서 수영을 하거나, 자전거를 타고 주변 마을을 탐험할 수 있습니다. 명상과 요가 클래스도 인기 있습니다.
#
# 이 세 곳 모두 따뜻한 날씨와 함께 자연 경관 및 역사적인 장소들이 조화를 이루고 있어, 사용자의 여행 취향에 잘 맞는 여행지입니다.
#  사용자 입력 :
# 나는 여름 휴가를 계획 중이야. 따뜻한 날씨를 좋아하고, 자연 경관과 역사적인 장소를 둘러보는 걸 좋아해.
# 어떤 여행지가 나에게 적합할까?
#
#
#
#  == 단계 3 ==
#
#  프롬프트 :
#  사용자가 하루 동안 이 여행지에서 시간을 보낼 계획입니다.
# 오전, 오후, 저녁으로 나누어 일정을 짜고, 각 시간대에 어떤 활동을 하면 좋을지 설명하세요.
#
#
#  문맥(Context):
#  저는 **산토리니, 그리스**를 선택하겠습니다. 그 이유는 다음과 같습니다.
#
# 1. **아름다운 자연 경관**: 산토리니는 화산섬으로서 경치가 뛰어나며, 특히 일몰이 아름다운 오이아 마을의 경치가 인상적입니다. 맑고 푸른 바다와 하얀 건물의 조화는 정말 매력적입니다.
#
# 2. **역사 탐방**: 고대 티라 유적지는 그리스의 풍부한 역사와 문화유산을 탐험할 수 있는 좋은 장소입니다. 이곳에서 고대 문명의 흔적을 직접 느낄 수 있습니다.
#
# 3. **따뜻한 날씨**: 여름철 평균 기온이 28~30도로 따뜻하고 맑은 날씨가 지속되어 야외 활동에 매우 적합합니다.
#
# 4. **음식 체험**: 그리스 전통 요리를 맛볼 수 있는 좋은 기회가 많아, 지중해 식단을 즐기면서 여행의 즐거움을 더할 수 있습니다.
#
# 5. **여러 활동의 조화**: 하이킹, 보트 투어, 와인 시음 등 다양한 활동을 통해 자연과 문화를 동시에 경험할 수 있습니다.
#
# 이제 선택한 산토리니에서 즐길 수 있는 주요 활동 5가지를 나열해보겠습니다.
#
# 1. **하이킹**: 산토리니의 절경을 감상하며 일몰을 바라보는 트레킹 코스인 '오이아에서 피라까지' 하이킹을 즐길 수 있습니다.
#
# 2. **고대 티라 유적지 탐방**: 고대 그리스 문명의 유적으로, 역사적인 건축물과 유적들을 확인하며 역사에 대해 배울 수 있는 기회입니다.
#
# 3. **와인 시음 투어**: 지역에서 생산되는 다양한 그리스 와인을 맛볼 수 있는 투어에 참여하여 맛과 향을 즐길 수 있습니다.
#
# 4. **페리사 해변에서 바다 즐기기**: 검은 모래 해변에서 수영이나 일광욕을 하며 편안한 시간을 보낼 수 있습니다.
#
# 5. **전통 그리스 요리 체험**: 지역 레스토랑이나 요리 교실에서 미고그리도와 같은 전통 요리를 체험할 수 있는 기회를 가질 수 있습니다.
#
# 산토리니는 사용자의 취향에 잘 맞는 여행지로, 자연과 역사를 동시에 탐험하는 데 최적의 장소가 될 것입니다.
#  사용자 입력 :
# 나는 여름 휴가를 계획 중이야. 따뜻한 날씨를 좋아하고, 자연 경관과 역사적인 장소를 둘러보는 걸 좋아해.
# 어떤 여행지가 나에게 적합할까?
#
#
# 여름 휴가에 적합한 여행지로는 다음과 같은 곳들을 추천합니다:
#
# 1. **산토리니, 그리스**: 아름다운 일몰, 독특한 화산섬 경관과 그리스 고대 유적지 탐방이 가능하며, 평균 기온이 따뜻해 여름 여행에 적합합니다.
#
# 2. **타이, 푸켓**: 끝없이 펼쳐진 해변과 푸른 바다, 다양한 수상 활동을 즐길 수 있는 장소입니다. 또한, 역사적인 사원과 문화 체험도 가능합니다.
#
# 3. **이탈리아, 아말피 해안**: 절벽에 지어진 아름다운 마을과 함께 해양 스포츠, 현지 음식을 즐길 수 있습니다. 날씨가 따뜻하고 경치가 매우 아름답습니다.
#
# 4. **크로아티아, 두브로브니크**: 고대 도시 성벽과 아름다운 해변을 동시에 느낄 수 있는 곳으로, 여름에 따뜻한 날씨와 탁 트인 바다를 만끽할 수 있습니다.
#
# 5. **스페인, 발렌시아**: 고대 유적물과 현대 건축이 어우러진 도시로, 해변과 맛있는 스페인 요리, 특히 파에야로 유명합니다. 따뜻한 날씨와 다양한 문화 체험이 가능합니다.
#
# 이 포인트들을 고려해보시고, 본인의 취향에 맞는 여행지를 결정하시면 좋겠습니다!

# %% [markdown]
# ### 2. Routing

# %%
def run_router_workflow(user_prompt:str):
    router_prompt = f"""
    사용자의 프롬프트/질문: {user_prompt}

    각 모델은 서로 다른 기능을 가지고 있습니다. 사용자의 질문에 가장 적합한 모델을 선택하세요:
    
    gpt-4o: 일반적인 작업에 가장 적합한 모델 (기본값)
    gpt-5.2: 코딩 및 복잡한 문제 해결에 적합한 모델
    gpt-4o-mini: 간단한 사칙연산 등의 작업에 적합한 모델

    모델명만 단답형으로 응답하세요
    """
    selected_model = llm_call(router_prompt)
    response = llm_call(user_prompt, model = selected_model)
    return response

# %%
query1 = '1더하기2는 뭐지?'
response = run_router_workflow(query1)
print(response)
# Out:
# 1 더하기 2는 3입니다.

# %%
query1 = '리스본 여행 일정 짜줘'
response = run_router_workflow(query1)
print(response)
# Out:
# 리스본은 역사, 문화, 음식이 풍부한 멋진 도시입니다. 여정 계획을 위해 3일 일정으로 간단한 예시를 제안해드리겠습니다.
#
# ### 첫째 날: 역사와 문화 탐방
# - **아침**
#   - 베렌 파스티스(19세기 콘센트)에서 `Pastel de Belém` 시식.
#   - 제리미토스 수도원(Jerónimos Monastery) 방문: 마누엘 양식의 건축물.
#
# - **점심**
#   - 즉석에서 현지 카페에서 샌드위치 및 커피 즐기기.
#
# - **오후**
#   - 베렌 타워(Torre de Belém) 탐방: 항해 시대의 기념비.
#   - 해양 박물관(Museu de Marinha) 방문하여 포르투갈의 항해 역사를 배워보기.
#
# - **저녁**
#   - 알칸타라 지역의 레스토랑에서 포르투갈 전통 요리와 포르투갈 와인 시음.
#
# ### 둘째 날: 도심과 쇼핑
# - **아침**
#   - 상 조르제 성(Castelo de São Jorge)에서 도시 전경 감상.
#   - 알파마 지구를 산책하며 지역의 예술품 및 기념품 쇼핑.
#
# - **점심**
#   - 현지 레스토랑에서 바칼라우(포르투갈 전통 대구 요리) 체험.
#
# - **오후**
#   - 바이샤 지역 탐방: Rua Augusta, Praça do Comércio 등 주요 거리와 광장 둘러보기.
#   - 리베르다데 대로(Avenida da Liberdade)에서 쇼핑.
#
# - **저녁**
#   - 로씨오 광장 근처 파두 공연을 즐기며 저녁 식사.
#
# ### 셋째 날: 현대와 자연
# - **아침**
#   - 칼루스테 굴벤키안 미술관 방문: 대규모의 예술품 컬렉션.
#
# - **점심**
#   - 근처 카페에서 간단한 브런치.
#
# - **오후**
#   - 리스본 오세아나리움(대서양 관람) 탐방.
#   - 파르케 다스 나소에스(Parque das Nações)에서 휴식 및 산책.
#
# - **저녁**
#   - 테주강 주변의 레스토랑에서 해산물 요리로 여정 마무리.
#
# 이 일정은 기본적인 틀이며, 각자의 관심사에 따라 조정 가능합니다. 리스본은 대중교통이 잘 되어 있어 쉽게 이동할 수 있으며 각 명소 주변에 숨겨진 작은 가게와 카페들이 많으니 천천히 둘러보시는 것도 좋습니다. 즐거운 여행 되세요!

# %%
query1 = '파이썬으로 API 웹서버를 만들어줘'
response = run_router_workflow(query1)
print(response)
# Out:
# 아래는 **파이썬으로 바로 실행 가능한 API 웹서버 예시**입니다. 가장 흔히 쓰는 **FastAPI**로 만들었고, `GET/POST`, 파라미터, JSON 응답까지 포함했습니다.
#
# ## 1) 설치
# ```bash
# pip install fastapi uvicorn
# ```
#
# ## 2) 서버 코드 (`main.py`)
# ```python
# from fastapi import FastAPI, Query
# from pydantic import BaseModel
# from typing import Optional
# from datetime import datetime
#
# app = FastAPI(title="Sample API Server", version="1.0.0")
#
# # 간단한 헬스체크
# @app.get("/health")
# def health():
#     return {"status": "ok", "time": datetime.utcnow().isoformat()}
#
# # Query parameter 예시: /hello?name=철수
# @app.get("/hello")
# def hello(name: str = Query("world", min_length=1)):
#     return {"message": f"Hello, {name}!"}
#
# # POST JSON 바디 예시
# class Item(BaseModel):
#     name: str
#     price: float
#     description: Optional[str] = None
#
# # 임시 DB(메모리)
# ITEMS: dict[int, Item] = {}
#
# @app.post("/items", status_code=201)
# def create_item(item: Item):
#     new_id = (max(ITEMS.keys()) + 1) if ITEMS else 1
#     ITEMS[new_id] = item
#     return {"id": new_id, "item": item}
#
# @app.get("/items/{item_id}")
# def get_item(item_id: int):
#     item = ITEMS.get(item_id)
#     if not item:
#         return {"error": "not found"}
#     return {"id": item_id, "item": item}
# ```
#
# ## 3) 실행
# ```bash
# uvicorn main:app --reload --host 0.0.0.0 --port 8000
# ```
#
# ## 4) 테스트
# - 브라우저/Swagger 문서:
#   `http://localhost:8000/docs`
# - 헬스체크:
#   ```bash
#   curl http://localhost:8000/health
#   ```
# - POST 테스트:
#   ```bash
#   curl -X POST http://localhost:8000/items \
#     -H "Content-Type: application/json" \
#     -d '{"name":"pen","price":1.2,"description":"blue"}'
#   ```
#
# 원하는 형태를 맞춰줄게요.
# 1) **어떤 API**가 필요해요? (예: 로그인/회원, 게시판, 파일업로드, 크롤링 결과 제공 등)
# 2) **DB**는 쓸까요? (SQLite/PostgreSQL/MySQL/없음)
# 3) 배포는 로컬/도커/클라우드 중 어디로 할까요?
