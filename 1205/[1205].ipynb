# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
def AND(x1, x2):
  result = 0.5*x1 + 0.5*x2 - 0.7
  if result <= 0:
    return 0
  else:
    return 1

# %%
AND(0,0)
# Out:
# 0

# %%
AND(1,2)
# Out:
# 1

# %%
AND(1,1)
# Out:
# 1

# %%
x1 = np.arange(-1, 3, 0.1)
x2 = -x1 + (0.7/0.5)
plt.plot(x1,x2)
plt.grid()

# %%
# !python --version
# Out:
# Python 3.12.12

# %%
def AND(x1, x2, x3=1):
  X = np.array([x1, x2])
  w = np.array([0.5,0.5])
  b = x3 * (-0.7)
  y = np.dot(X, w) + b
  if y <= 0:
    return 0
  else:
    return 1

# %%
a = np.array([1,2])

# %%
a
# Out:
# array([1, 2])

# %%
a[0]
# Out:
# np.int64(1)

# %%
b = np.array([10, 100])

# %%
np.dot(a,b)
# Out:
# np.int64(210)

# %% [markdown]
# (1,2) dot (10, 100) = 10 + 200 = 10 * 1 + 100 * 2 = 210

# %%
def step_func(x):
  if x > 0 :
    return 1
  else:
    return 0

# %%
def sigmoid(x):
  return 1 / (1 + np.exp(-x))

# %%
def relu(x):
  return np.maximum(0,x)

# %%
relu(10)
# Out:
# np.int64(10)

# %%
x = np.arange(-100, 100, 0.1)
y = relu(x)
plt.plot(x, y)
plt.grid()
plt.show()

# %%
x = np.arange(-10,5,0.1)
y = sigmoid(x)
plt.plot(x,y)
plt.grid()
plt.show()

# %%
import numpy as np
np.random.seed(42)
data = np.random.random((1000,100))
labels = np.random.randint(2, size=(1000,1))

# %%
data
# Out:
# array([[0.37454012, 0.95071431, 0.73199394, ..., 0.42754102, 0.02541913,
#         0.10789143],
#        [0.03142919, 0.63641041, 0.31435598, ..., 0.89711026, 0.88708642,
#         0.77987555],
#        [0.64203165, 0.08413996, 0.16162871, ..., 0.21582103, 0.62289048,
#         0.08534746],
#        ...,
#        [0.64514754, 0.70667252, 0.23104766, ..., 0.51084343, 0.67891919,
#         0.60043148],
#        [0.98141724, 0.77014426, 0.96548648, ..., 0.19728342, 0.80690844,
#         0.26968104],
#        [0.40106312, 0.51576188, 0.60996234, ..., 0.67445341, 0.49944724,
#         0.38990849]])

# %%
len(data)
# Out:
# 1000

# %%
len(data[1])
# Out:
# 100

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation

# %%
model = Sequential()
model.add(Dense(32,activation='relu', input_dim=100))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(data, labels, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5479 - loss: 0.6900
# Epoch 2/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5410 - loss: 0.6902
# Epoch 3/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5465 - loss: 0.6862
# Epoch 4/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6038 - loss: 0.6653
# Epoch 5/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5955 - loss: 0.6720
# Epoch 6/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6177 - loss: 0.6677
# Epoch 7/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6347 - loss: 0.6588
# Epoch 8/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6096 - loss: 0.6567
# Epoch 9/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6537 - loss: 0.6476
# Epoch 10/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6052 - loss: 0.6482

# %%
model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_12 (Dense)                │ (None, 32)             │         3,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,532 (25.52 KB)
#  Trainable params: 3,265 (12.75 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 3,267 (12.77 KB)
