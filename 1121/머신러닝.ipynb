# %% [markdown]
# # 머신러닝 : 머신러닝 개요 및 회귀

# %% [markdown]
# ## 머신러닝 개요

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 머신러닝 프로세스

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 데이터 전처리 : Feature Engineering

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 모델 선택

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 모델 학습

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 모델 평가

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 모델 배포

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Scikit-learn 라이브러리

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ## 지도학습 : 회귀(Regression)
